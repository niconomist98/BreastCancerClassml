# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_parquet('../data/interim/BreastCancer.parquet')

# %%
df
# Out:
#        index  perimeter_se  radius_worst  concave points_mean  \
# 0      279.0          1.83           NaN             0.037110
# 1      307.0       1144.00       9699.00             0.003472
# 2      576.0       2183.00           NaN             0.022780
# 3      350.0       2225.00         13.28             0.011620
# 4      120.0       1103.00         12.82             0.026230
# ...      ...           ...           ...                  ...
# 16175  602.0       2844.00           NaN             0.056130
# 16176  350.0       2225.00           NaN             0.011620
# 16177  442.0       2235.00         15.27             0.009937
# 16178  501.0       2974.00         16.01             0.067590
# 16179  233.0       3767.00         24.47             0.083400
#
#        smoothness_mean  area_mean  concavity_se  texture_mean  \
# 0              0.09516      587.4      0.014570         15.18
# 1                  NaN      246.3      0.003681         14.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16180 entries, 0 to 16179
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    16180 non-null  float64
#  1   perimeter_se             13640 non-null  float64
#  2   radius_worst             13630 non-null  float64
#  3   concave points_mean      13600 non-null  float64
#  4   smoothness_mean          13450 non-null  float64
#  5   area_mean                13425 non-null  float64
#  6   concavity_se             13475 non-null  float64
#  7   texture_mean             13565 non-null  float64
#  8   concavity_worst          13540 non-null  float64
#  9   smoothness_se            13610 non-null  float64
#  10  concave points_se        13600 non-null  float64
#  11  area_worst               13530 non-null  float64
#  12  compactness_mean         13480 non-null  float64
# ...

# %%
df['diagnosis']=df['diagnosis'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16180 entries, 0 to 16179
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    16180 non-null  float64
#  1   perimeter_se             13640 non-null  float64
#  2   radius_worst             13630 non-null  float64
#  3   concave points_mean      13600 non-null  float64
#  4   smoothness_mean          13450 non-null  float64
#  5   area_mean                13425 non-null  float64
#  6   concavity_se             13475 non-null  float64
#  7   texture_mean             13565 non-null  float64
#  8   concavity_worst          13540 non-null  float64
#  9   smoothness_se            13610 non-null  float64
#  10  concave points_se        13600 non-null  float64
#  11  area_worst               13530 non-null  float64
#  12  compactness_mean         13480 non-null  float64
# ...

# %%
df_t=df.T #df transpuesto

# %%
df_t = df_t[df_t.columns[~df_t.isnull().any()]]
df_t
# Out:
#                                  3              13            18     \
# index                       350.000000     562.000000  3.120000e+02
# perimeter_se               2225.000000    2362.000000  2.346000e+03
# radius_worst                 13.280000      17.520000  1.419000e+01
# concave points_mean           0.011620       0.094290  2.548000e-02
# smoothness_mean               0.075610       0.104800  8.794000e-02
# area_mean                   421.000000     716.900000  5.041000e+02
# concavity_se                  0.005949       0.073590  3.137000e-02
# texture_mean                 17.070000      30.620000  1.337000e+01
# concavity_worst               0.030460       1.170000  1.769000e-01
# smoothness_se                 0.006583       0.004625  6.494000e-03
# concave points_se             0.006296       0.016080  1.069000e-02
# area_worst                  542.500000     915.000000  6.188000e+02
# compactness_mean              0.036300       0.208700  7.948000e-02
# ...

# %%
df=df_t
df
# Out:
#                                  3              13            18     \
# index                       350.000000     562.000000  3.120000e+02
# perimeter_se               2225.000000    2362.000000  2.346000e+03
# radius_worst                 13.280000      17.520000  1.419000e+01
# concave points_mean           0.011620       0.094290  2.548000e-02
# smoothness_mean               0.075610       0.104800  8.794000e-02
# area_mean                   421.000000     716.900000  5.041000e+02
# concavity_se                  0.005949       0.073590  3.137000e-02
# texture_mean                 17.070000      30.620000  1.337000e+01
# concavity_worst               0.030460       1.170000  1.769000e-01
# smoothness_se                 0.006583       0.004625  6.494000e-03
# concave points_se             0.006296       0.016080  1.069000e-02
# area_worst                  542.500000     915.000000  6.188000e+02
# compactness_mean              0.036300       0.208700  7.948000e-02
# ...

# %%
df=df_t.T
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3230 entries, 3 to 16178
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    3230 non-null   float64
#  1   perimeter_se             3230 non-null   float64
#  2   radius_worst             3230 non-null   float64
#  3   concave points_mean      3230 non-null   float64
#  4   smoothness_mean          3230 non-null   float64
#  5   area_mean                3230 non-null   float64
#  6   concavity_se             3230 non-null   float64
#  7   texture_mean             3230 non-null   float64
#  8   concavity_worst          3230 non-null   float64
#  9   smoothness_se            3230 non-null   float64
#  10  concave points_se        3230 non-null   float64
#  11  area_worst               3230 non-null   float64
#  12  compactness_mean         3230 non-null   float64
# ...

# %%
df=df.drop_duplicates(keep='first', ignore_index=False)

# %%
df
# Out:
#       index  perimeter_se  radius_worst  concave points_mean  smoothness_mean  \
# 3     350.0        2225.0         13.28              0.01162          0.07561
# 13    562.0        2362.0         17.52              0.09429          0.10480
# 18    312.0        2346.0         14.19              0.02548          0.08794
# 22    341.0        1429.0         10.75              0.02292          0.08481
# 45      8.0        2406.0         15.49              0.09353          0.12730
# ...     ...           ...           ...                  ...              ...
# 3213  408.0        3061.0         21.08              0.08824          0.10360
# 3214  635.0        1657.0         14.34              0.01762          0.08369
# 3220  184.0        1344.0         17.80              0.03263          0.09057
# 3221  561.0        2041.0         11.92              0.00000          0.07449
# 3234  501.0        2974.0         16.01              0.06759          0.11620
#
# ...

# %%
df.duplicated(subset='index', keep='first').sum()
# Out:
# 0

# %%
df['index'].value_counts()
# Out:
# 350.0    1
# 171.0    1
# 201.0    1
# 176.0    1
# 490.0    1
#         ..
# 431.0    1
# 117.0    1
# 243.0    1
# 627.0    1
# 501.0    1
# Name: index, Length: 641, dtype: int64

# %%
df=df.drop_duplicates(subset='index',keep='first', ignore_index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 3 to 3234
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    641 non-null    float64
#  1   perimeter_se             641 non-null    float64
#  2   radius_worst             641 non-null    float64
#  3   concave points_mean      641 non-null    float64
#  4   smoothness_mean          641 non-null    float64
#  5   area_mean                641 non-null    float64
#  6   concavity_se             641 non-null    float64
#  7   texture_mean             641 non-null    float64
#  8   concavity_worst          641 non-null    float64
#  9   smoothness_se            641 non-null    float64
#  10  concave points_se        641 non-null    float64
#  11  area_worst               641 non-null    float64
#  12  compactness_mean         641 non-null    float64
# ...

# %%
df=df.drop('id',axis=1)

# %%
df
# Out:
#       index  perimeter_se  radius_worst  concave points_mean  smoothness_mean  \
# 3     350.0        2225.0         13.28              0.01162          0.07561
# 13    562.0        2362.0         17.52              0.09429          0.10480
# 18    312.0        2346.0         14.19              0.02548          0.08794
# 22    341.0        1429.0         10.75              0.02292          0.08481
# 45      8.0        2406.0         15.49              0.09353          0.12730
# ...     ...           ...           ...                  ...              ...
# 3213  408.0        3061.0         21.08              0.08824          0.10360
# 3214  635.0        1657.0         14.34              0.01762          0.08369
# 3220  184.0        1344.0         17.80              0.03263          0.09057
# 3221  561.0        2041.0         11.92              0.00000          0.07449
# 3234  501.0        2974.0         16.01              0.06759          0.11620
#
# ...

# %%
df=df.drop_duplicates(keep='first', ignore_index=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 3 to 3234
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    641 non-null    float64
#  1   perimeter_se             641 non-null    float64
#  2   radius_worst             641 non-null    float64
#  3   concave points_mean      641 non-null    float64
#  4   smoothness_mean          641 non-null    float64
#  5   area_mean                641 non-null    float64
#  6   concavity_se             641 non-null    float64
#  7   texture_mean             641 non-null    float64
#  8   concavity_worst          641 non-null    float64
#  9   smoothness_se            641 non-null    float64
#  10  concave points_se        641 non-null    float64
#  11  area_worst               641 non-null    float64
#  12  compactness_mean         641 non-null    float64
# ...

# %%
df=df.drop('index',axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 3 to 3234
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   perimeter_se             641 non-null    float64
#  1   radius_worst             641 non-null    float64
#  2   concave points_mean      641 non-null    float64
#  3   smoothness_mean          641 non-null    float64
#  4   area_mean                641 non-null    float64
#  5   concavity_se             641 non-null    float64
#  6   texture_mean             641 non-null    float64
#  7   concavity_worst          641 non-null    float64
#  8   smoothness_se            641 non-null    float64
#  9   concave points_se        641 non-null    float64
#  10  area_worst               641 non-null    float64
#  11  compactness_mean         641 non-null    float64
#  12  radius_mean              641 non-null    float64
# ...

# %%
df=df.drop_duplicates(keep='first', ignore_index=False)

# %%
df
# Out:
#       perimeter_se  radius_worst  concave points_mean  smoothness_mean  \
# 3           2225.0         13.28              0.01162          0.07561
# 13          2362.0         17.52              0.09429          0.10480
# 18          2346.0         14.19              0.02548          0.08794
# 22          1429.0         10.75              0.02292          0.08481
# 45          2406.0         15.49              0.09353          0.12730
# ...            ...           ...                  ...              ...
# 3205        7222.0         33.13              0.19130          0.11490
# 3213        3061.0         21.08              0.08824          0.10360
# 3220        1344.0         17.80              0.03263          0.09057
# 3221        2041.0         11.92              0.00000          0.07449
# 3234        2974.0         16.01              0.06759          0.11620
#
#       area_mean  concavity_se  texture_mean  concavity_worst  smoothness_se  \
# ...

# %%
df.to_parquet("../data/interim/Breastcleandefi.parquet", index = False)

# %%
df.dropna(thresh=24)
# Out:
#       perimeter_se  radius_worst  concave points_mean  smoothness_mean  \
# 3           2225.0         13.28              0.01162          0.07561
# 13          2362.0         17.52              0.09429          0.10480
# 18          2346.0         14.19              0.02548          0.08794
# 22          1429.0         10.75              0.02292          0.08481
# 45          2406.0         15.49              0.09353          0.12730
# ...            ...           ...                  ...              ...
# 3205        7222.0         33.13              0.19130          0.11490
# 3213        3061.0         21.08              0.08824          0.10360
# 3220        1344.0         17.80              0.03263          0.09057
# 3221        2041.0         11.92              0.00000          0.07449
# 3234        2974.0         16.01              0.06759          0.11620
#
#       area_mean  concavity_se  texture_mean  concavity_worst  smoothness_se  \
# ...

# %%
(df.isnull().sum()*100/len(df))
# Out:
# perimeter_se               0.0
# radius_worst               0.0
# concave points_mean        0.0
# smoothness_mean            0.0
# area_mean                  0.0
# concavity_se               0.0
# texture_mean               0.0
# concavity_worst            0.0
# smoothness_se              0.0
# concave points_se          0.0
# area_worst                 0.0
# compactness_mean           0.0
# radius_mean                0.0
# area_se                    0.0
# concave points_worst       0.0
# fractal_dimension_worst    0.0
# perimeter_worst            0.0
# texture_se                 0.0
# fractal_dimension_mean     0.0
# texture_worst              0.0
# smoothness_worst           0.0
# concavity_mean             0.0
# symmetry_mean              0.0
# symmetry_worst             0.0
# diagnosis                  0.0
# fractal_dimension_se       0.0
# perimeter_mean             0.0
# compactness_worst          0.0
# symmetry_se                0.0
# compactness_se             0.0
# ...

# %%
df.describe()
# Out:
#        perimeter_se  radius_worst  concave points_mean  smoothness_mean  \
# count    569.000000    569.000000           569.000000       569.000000
# mean    2549.980718    315.194921             2.366459         4.304801
# std     1757.074266   1655.459336            16.155145        21.074558
# min        0.771400      7.930000             0.000000         0.052630
# 25%     1491.000000     13.180000             0.020310         0.086410
# 50%     2155.000000     15.150000             0.033900         0.095940
# 75%     3176.000000     19.850000             0.077260         0.106100
# max     9807.000000   9981.000000           162.000000       123.000000
#
#          area_mean  concavity_se  texture_mean  concavity_worst  \
# count   569.000000    569.000000    569.000000       569.000000
# mean    654.889104      1.153794     19.289649        26.723742
# std     351.914129     17.470924      4.301036       114.204035
# ...
